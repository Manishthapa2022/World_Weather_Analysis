# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longtitude combinations.
lats=np.random.uniform(-90,90, size=1500)
lngs=np.random.uniform(-180,180,size=1500)
lat_lngs=zip(lats, lngs)
coordinates=list(lat_lngs)

# %%
from citipy import citipy

# %%
# generate a list for holding the cities
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# # Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %%
# import the time library and the datetime module from the datetime library
import time
from datetime import datetime
# import the API key
from config import weather_api_key
url= "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key
#city = "Boston"
#query_url = url + "&q=" + city
#print(query_url)

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list 
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count=1
        time.sleep(60)
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count
    record_count+=1
# Run the API request for each of the cities
    try:
        # Parse the json and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list
        city_data.append({"City":city.title(),
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Humidity":city_humidity,
                          "Cloudiness":city_clouds,
                          "Wind Speed":city_wind,
                          "Country":city_country,
                          "Date":city_date})
    # If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | tapes
# Processing Record 2 of Set 1 | ocean city
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | olafsvik
# Processing Record 5 of Set 1 | kandrian
# Processing Record 6 of Set 1 | hasaki
# Processing Record 7 of Set 1 | ferrol
# Processing Record 8 of Set 1 | chuy
# Processing Record 9 of Set 1 | fortuna
# Processing Record 10 of Set 1 | coihaique
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | vao
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | vestmannaeyjar
# Processing Record 17 of Set 1 | mabaruma
# Processing Record 18 of Set 1 | ureshino
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | alofi
# Processing Record 23 of Set 1 | tautira
# Processing Record 24 of Set 1 | anadyr
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | van wert
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | rio gallegos
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | djambala
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | burns lake
# Processing Record 35 of Set 1 | sokoni
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | vardo
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | goundam
# Processing Record 43 of Set 1 | chake chake
# Processing Record 44 of Set 1 | istisu
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | samarai
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | marathon
# Processing Record 2 of Set 2 | mpika
# Processing Record 3 of Set 2 | geraldton
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | mount isa
# Processing Record 6 of Set 2 | lake havasu city
# Processing Record 7 of Set 2 | jumla
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 2 | luganville
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | karla
# Processing Record 17 of Set 2 | pontes e lacerda
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | natal
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 2 | gazli
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | klang
# Processing Record 28 of Set 2 | ola
# Processing Record 29 of Set 2 | hofn
# Processing Record 30 of Set 2 | tamiahua
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | namibe
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | savannah bight
# Processing Record 37 of Set 2 | magole
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | peleduy
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | zhezkazgan
# Processing Record 43 of Set 2 | sept-iles
# Processing Record 44 of Set 2 | meulaboh
# Processing Record 45 of Set 2 | mabama
# Processing Record 46 of Set 2 | miraflores
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 3 | nome
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | ostrovnoy
# Processing Record 4 of Set 3 | pandhurna
# Processing Record 5 of Set 3 | rupert
# Processing Record 6 of Set 3 | atar
# Processing Record 7 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 3 | lagoa
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | cabedelo
# Processing Record 11 of Set 3 | peterhead
# Processing Record 12 of Set 3 | odweyne
# Processing Record 13 of Set 3 | sur
# Processing Record 14 of Set 3 | portland
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | seoul
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | tyrma
# Processing Record 19 of Set 3 | rajauri
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | valparaiso
# Processing Record 22 of Set 3 | terekli-mekteb
# Processing Record 23 of Set 3 | marsa matruh
# Processing Record 24 of Set 3 | hirara
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | mount gambier
# Processing Record 27 of Set 3 | malanville
# Processing Record 28 of Set 3 | comodoro rivadavia
# Processing Record 29 of Set 3 | jurado
# Processing Record 30 of Set 3 | bahia blanca
# Processing Record 31 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | padang
# Processing Record 34 of Set 3 | bluff
# Processing Record 35 of Set 3 | yukhnov
# Processing Record 36 of Set 3 | quang ngai
# Processing Record 37 of Set 3 | codrington
# Processing Record 38 of Set 3 | kaoma
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | guiglo
# Processing Record 44 of Set 3 | maiduguri
# Processing Record 45 of Set 3 | kahului
# Processing Record 46 of Set 3 | alta floresta
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | zuenoula
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | methoni
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 4 | missoula
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | flinders
# Processing Record 8 of Set 4 | carutapera
# Processing Record 9 of Set 4 | zaysan
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | sabha
# Processing Record 12 of Set 4 | vangaindrano
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | darhan
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | abashiri
# Processing Record 21 of Set 4 | belaya gora
# Processing Record 22 of Set 4 | avera
# Processing Record 23 of Set 4 | pipri
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | hervey bay
# Processing Record 26 of Set 4 | doha
# Processing Record 27 of Set 4 | beloha
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | barrow
# Processing Record 30 of Set 4 | mnogovershinnyy
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | gold coast
# Processing Record 33 of Set 4 | neuquen
# Processing Record 34 of Set 4 | chippewa falls
# Processing Record 35 of Set 4 | la romana
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | port blair
# Processing Record 38 of Set 4 | natitingou
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | nedjo
# Processing Record 41 of Set 4 | crotone
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | mersing
# Processing Record 44 of Set 4 | curuguaty
# Processing Record 45 of Set 4 | shonguy
# Processing Record 46 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 4 | alberdi
# Processing Record 48 of Set 4 | constitucion
# Processing Record 49 of Set 4 | brownfield
# Processing Record 50 of Set 4 | humaita
# Processing Record 1 of Set 5 | palermo
# Processing Record 2 of Set 5 | ust-nera
# Processing Record 3 of Set 5 | northview
# Processing Record 4 of Set 5 | nhulunbuy
# Processing Record 5 of Set 5 | kuytun
# Processing Record 6 of Set 5 | kamenka
# Processing Record 7 of Set 5 | taketa
# Processing Record 8 of Set 5 | duluth
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | kemijarvi
# Processing Record 11 of Set 5 | severo-yeniseyskiy
# Processing Record 12 of Set 5 | dharmanagar
# Processing Record 13 of Set 5 | marzuq
# Processing Record 14 of Set 5 | solnechnyy
# Processing Record 15 of Set 5 | san quintin
# Processing Record 16 of Set 5 | iskateley
# Processing Record 17 of Set 5 | alghero
# Processing Record 18 of Set 5 | apple valley
# Processing Record 19 of Set 5 | college
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | arequipa
# Processing Record 23 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 24 of Set 5 | valleyview
# Processing Record 25 of Set 5 | kearney
# Processing Record 26 of Set 5 | lumut
# Processing Record 27 of Set 5 | rizhao
# Processing Record 28 of Set 5 | kabo
# Processing Record 29 of Set 5 | oga
# Processing Record 30 of Set 5 | mackay
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | aragarcas
# Processing Record 33 of Set 5 | kolpashevo
# Processing Record 34 of Set 5 | manavalakurichi
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | narsaq
# Processing Record 37 of Set 5 | kavieng
# Processing Record 38 of Set 5 | kushmurun
# Processing Record 39 of Set 5 | nueve de julio
# Processing Record 40 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | baykit
# Processing Record 44 of Set 5 | jinchang
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | cananea
# Processing Record 47 of Set 5 | bubaque
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | lasa
# Processing Record 50 of Set 5 | lorengau
# Processing Record 1 of Set 6 | grindavik
# Processing Record 2 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | iqaluit
# Processing Record 5 of Set 6 | sao joao de pirabas
# Processing Record 6 of Set 6 | tucuman
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | mizdah
# Processing Record 9 of Set 6 | nelson bay
# Processing Record 10 of Set 6 | berezovyy
# Processing Record 11 of Set 6 | georgetown
# Processing Record 12 of Set 6 | belyy yar
# Processing Record 13 of Set 6 | dalby
# Processing Record 14 of Set 6 | bud
# Processing Record 15 of Set 6 | paamiut
# Processing Record 16 of Set 6 | butaritari
# Processing Record 17 of Set 6 | khani
# Processing Record 18 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 6 | price
# Processing Record 20 of Set 6 | maple creek
# Processing Record 21 of Set 6 | bela
# Processing Record 22 of Set 6 | yambio
# Processing Record 23 of Set 6 | saint simons
# Processing Record 24 of Set 6 | port macquarie
# Processing Record 25 of Set 6 | la ronge
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 6 | gilleleje
# Processing Record 29 of Set 6 | anantapur
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | buala
# Processing Record 32 of Set 6 | turulung
# Processing Record 33 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 34 of Set 6 | moanda
# Processing Record 35 of Set 6 | moron
# Processing Record 36 of Set 6 | plattsburgh
# Processing Record 37 of Set 6 | chulumani
# Processing Record 38 of Set 6 | serebryansk
# Processing Record 39 of Set 6 | arman
# Processing Record 40 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set
# Processing Record 37 of Set 9 | yuksekova
# Processing Record 38 of Set 9 | maua
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | vila velha
# Processing Record 41 of Set 9 | norman wells
# Processing Record 42 of Set 9 | ponta do sol
# Processing Record 43 of Set 9 | socorro
# Processing Record 44 of Set 9 | moundou
# Processing Record 45 of Set 9 | pochutla
# Processing Record 46 of Set 9 | cangucu
# Processing Record 47 of Set 9 | kaeo
# Processing Record 48 of Set 9 | sarab
# Processing Record 49 of Set 9 | kruisfontein
# Processing Record 50 of Set 9 | mazyr
# Processing Record 1 of Set 10 | brewster
# Processing Record 2 of Set 10 | port augusta
# Processing Record 3 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 4 of Set 10 | cidreira
# Processing Record 5 of Set 10 | acapulco
# Processing Record 6 of Set 10 | svetlogorsk
# Processing Record 7 of Set 10 | shetpe
# Processing Record 8 of Set 10 | sao filipe
# Processing Record 9 of Set 10 | samarkand
# Processing Record 10 of Set 10 | inirida
# Processing Record 11 of Set 10 | maarianhamina
# Processing Record 12 of Set 10 | ceska lipa
# Processing Record 13 of Set 10 | sakaiminato
# Processing Record 14 of Set 10 | roald
# Processing Record 15 of Set 10 | itacare
# Processing Record 16 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 10 | klaksvik
# Processing Record 18 of Set 10 | mporokoso
# Processing Record 19 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 20 of Set 10 | homer
# Processing Record 21 of Set 10 | marawi
# Processing Record 22 of Set 10 | umea
# Processing Record 23 of Set 10 | mangrol
# Processing Record 24 of Set 10 | jiuquan
# Processing Record 25 of Set 10 | camacari
# Processing Record 26 of Set 10 | san isidro
# Processing Record 27 of Set 10 | nchelenge
# Processing Record 28 of Set 10 | okha
# Processing Record 29 of Set 10 | plainview
# Processing Record 30 of Set 10 | goderich
# Processing Record 31 of Set 10 | marica
# Processing Record 32 of Set 10 | saurimo
# Processing Record 33 of Set 10 | matara
# Processing Record 34 of Set 10 | asosa
# Processing Record 35 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 10 | cabangahan
# Processing Record 37 of Set 10 | domoni
# Processing Record 38 of Set 10 | oktyabrskiy
# Processing Record 39 of Set 10 | sinyavskoye
# Processing Record 40 of Set 10 | ahipara
# Processing Record 41 of Set 10 | raudeberg
# Processing Record 42 of Set 10 | kokopo
# Processing Record 43 of Set 10 | prince rupert
# Processing Record 44 of Set 10 | mulatupo
# Processing Record 45 of Set 10 | ceuta
# Processing Record 46 of Set 10 | brae
# Processing Record 47 of Set 10 | broken hill
# Processing Record 48 of Set 10 | kungurtug
# Processing Record 49 of Set 10 | san patricio
# Processing Record 50 of Set 10 | debre tabor
# Processing Record 1 of Set 11 | jimeta
# Processing Record 2 of Set 11 | inuvik
# Processing Record 3 of Set 11 | bam
# Processing Record 4 of Set 11 | oudtshoorn
# Processing Record 5 of Set 11 | parnaiba
# Processing Record 6 of Set 11 | shevchenkove
# Processing Record 7 of Set 11 | nong kung si
# Processing Record 8 of Set 11 | road town
# Processing Record 9 of Set 11 | batemans bay
# Processing Record 10 of Set 11 | hanna
# Processing Record 11 of Set 11 | iralaya
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | labuan
# Processing Record 14 of Set 11 | dzhebariki-khaya
# Processing Record 15 of Set 11 | sumbe
# Processing Record 16 of Set 11 | biu
# Processing Record 17 of Set 11 | panjab
# Processing Record 18 of Set 11 | kalengwa
# Processing Record 19 of Set 11 | pirganj
# Processing Record 20 of Set 11 | arrifes
# Processing Record 21 of Set 11 | biltine
# Processing Record 22 of Set 11 | jacareacanga
# Processing Record 23 of Set 11 | wyndham
# Processing Record 24 of Set 11 | hambantota
# Processing Record 25 of Set 11 | qui nhon
# Processing Record 26 of Set 11 | labytnangi
# Processing Record 27 of Set 11 | tobane
# Processing Record 28 of Set 11 | vryburg
# Processing Record 29 of Set 11 | el sauzal
# Processing Record 30 of Set 11 | santa marta
# Processing Record 31 of Set 11 | wanderlandia
# City not found. Skipping...
# Processing Record 32 of Set 11 | beira
# Processing Record 33 of Set 11 | werda
# Processing Record 34 of Set 11 | nara
# Processing Record 35 of Set 11 | pevek
# Processing Record 36 of Set 11 | bilma
# Processing Record 37 of Set 11 | faanui
# Processing Record 38 of Set 11 | kpandae
# Processing Record 39 of Set 11 | coquimbo
# Processing Record 40 of Set 11 | marsh harbour
# Processing Record 41 of Set 11 | champerico
# Processing Record 42 of Set 11 | uyuni
# Processing Record 43 of Set 11 | point fortin
# Processing Record 44 of Set 11 | quata
# Processing Record 45 of Set 11 | terrak
# Processing Record 46 of Set 11 | buraydah
# Processing Record 47 of Set 11 | bojnice
# Processing Record 48 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 11 | alexandria
# Processing Record 50 of Set 11 | tateyama
# Processing Record 1 of Set 12 | kapit
# Processing Record 2 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 12 | north bend
# Processing Record 4 of Set 12 | awbari
# Processing Record 5 of Set 12 | toora-khem
# Processing Record 6 of Set 12 | perbaungan
# Processing Record 7 of Set 12 | udachnyy
# Processing Record 8 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 12 | ekibastuz
# Processing Record 10 of Set 12 | brande
# Processing Record 11 of Set 12 | maloy
# Processing Record 12 of Set 12 | salantai
# Processing Record 13 of Set 12 | salinopolis
# Processing Record 14 of Set 12 | pishva
# Processing Record 15 of Set 12 | kpandu
# Processing Record 16 of Set 12 | wanning
# Processing Record 17 of Set 12 | wenling
# Processing Record 18 of Set 12 | lazurne
# Processing Record 19 of Set 12 | da nang
# Processing Record 20 of Set 12 | paranaiba
# Processing Record 21 of Set 12 | sinnamary
# Processing Record 22 of Set 12 | warri
# Processing Record 23 of Set 12 | najran
# Processing Record 24 of Set 12 | vung tau
# Processing Record 25 of Set 12 | aranos
# Processing Record 26 of Set 12 | vila franca do campo
# Processing Record 27 of Set 12 | bairiki
# Processing Record 28 of Set 12 | dekar
# Processing Record 29 of Set 12 | lagoa formosa
# Processing Record 30 of Set 12 | znamenskoye
# Processing Record 31 of Set 12 | saldanha
# Processing Record 32 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 12 | oussouye
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
len(city_data)
# Out:
# 542

# %%
#  Convert the array of dictionaries to a Pandas DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Tapes -30.6733  -51.3958     57.20        85           0        6.87
# 1  Ocean City  39.2776  -74.5746     59.99        93         100       13.00
# 2   Busselton -33.6500  115.3333     57.74        74          75       16.22
# 3    Olafsvik  64.8945  -23.7142     40.87        92         100       35.28
# 4    Kandrian  -6.2167  149.5500     84.49        74          94        5.01
# 5      Hasaki  35.7333  140.8333     75.60        82          91       25.23
# 6      Ferrol  43.4832   -8.2369     60.71        93          17        5.46
# 7        Chuy -33.6971  -53.4616     53.44        88           9        5.59
# 8     Fortuna  40.5982 -124.1573     68.94        70          70        3.00
# 9   Coihaique -45.5752  -72.0662     48.15        71          75        4.61
#
#   Country                 Date
# 0      BR  2022-10-04 23:49:36
# 1      US  2022-10-04 23:49:37
# 2      AU  2022-10-04 23:40:44
# 3      IS  2022-10-04 23:49:03
# 4      PG  2022-10-04 23:49:37
# 5      JP  2022-10-04 23:47:40
# 6      ES  2022-10-04 23:49:38
# 7      UY  2022-10-04 23:42:30
# 8      US  2022-10-04 23:45:18
# 9      CL  2022-10-04 23:48:02

# %%
# reorder the column so that the dataframe reads different
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0       Tapes      BR  2022-10-04 23:49:36 -30.6733  -51.3958     57.20
# 1  Ocean City      US  2022-10-04 23:49:37  39.2776  -74.5746     59.99
# 2   Busselton      AU  2022-10-04 23:40:44 -33.6500  115.3333     57.74
# 3    Olafsvik      IS  2022-10-04 23:49:03  64.8945  -23.7142     40.87
# 4    Kandrian      PG  2022-10-04 23:49:37  -6.2167  149.5500     84.49
# 5      Hasaki      JP  2022-10-04 23:47:40  35.7333  140.8333     75.60
# 6      Ferrol      ES  2022-10-04 23:49:38  43.4832   -8.2369     60.71
# 7        Chuy      UY  2022-10-04 23:42:30 -33.6971  -53.4616     53.44
# 8     Fortuna      US  2022-10-04 23:45:18  40.5982 -124.1573     68.94
# 9   Coihaique      CL  2022-10-04 23:48:02 -45.5752  -72.0662     48.15
#
#    Humidity  Cloudiness  Wind Speed
# 0        85           0        6.87
# 1        93         100       13.00
# 2        74          75       16.22
# 3        92         100       35.28
# 4        74          94        5.01
# 5        82          91       25.23
# 6        93          17        5.46
# 7        88           9        5.59
# 8        70          70        3.00
# 9        71          75        4.61

# %%
# Create a output csv file
output_data_file="weather_data/cities.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relelvant feilds from the DataFrame for plotting
lats=city_data_df["Lat"]
max_temps=city_data_df["Max Temp"]
humidity=city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# import time modulle 
# Build the scatter plot for latitude vs max ttemperature
plt.scatter(lats,
           max_temps,
           edgecolors="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")
# incorporate other graph properties
plt.title(f"City Latitude vs.Max Temperature" + time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
          
# Save figure
plt.savefig("weather_data/Fig1.png")
          
# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err)=linregress(x_values, y_values)
     # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13=city_data_df.loc[13]
index13
# Out:
# City                      Rikitea
# Country                        PF
# Date          2022-10-04 23:40:48
# Lat                      -23.1203
# Lng                     -134.9692
# Max Temp                     69.8
# Humidity                       65
# Cloudiness                     59
# Wind Speed                   24.0
# Name: 13, dtype: object

# %%
city_data_df["Lat"]>=0
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 537    False
# 538    False
# 539     True
# 540    False
# 541     True
# Name: Lat, Length: 542, dtype: bool

# %%
city_data_df.loc[city_data_df["Lat"]>=0].head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 1  Ocean City      US  2022-10-04 23:49:37  39.2776  -74.5746     59.99
# 3    Olafsvik      IS  2022-10-04 23:49:03  64.8945  -23.7142     40.87
# 5      Hasaki      JP  2022-10-04 23:47:40  35.7333  140.8333     75.60
# 6      Ferrol      ES  2022-10-04 23:49:38  43.4832   -8.2369     60.71
# 8     Fortuna      US  2022-10-04 23:45:18  40.5982 -124.1573     68.94
#
#    Humidity  Cloudiness  Wind Speed
# 1        93         100       13.00
# 3        92         100       35.28
# 5        82          91       25.23
# 6        93          17        5.46
# 8        70          70        3.00

# %%
# Create northern and southern hemisphere DataFrames
northern_hemi_df=city_data_df.loc[(city_data_df["Lat"]>=0)]
southern_hemi_df=city_data_df.loc[(city_data_df["Lat"]<=0)]

# %%
# Linear Regression on the Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,20))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-0.7676298599035991, intercept=89.20407474833543, rvalue=-0.8129346280125014, pvalue=1.9822832287908954e-88, stderr=0.02866553821841198, intercept_stderr=1.2504226225509374)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-40,40))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.6441521799501803, intercept=81.47161547411345, rvalue=0.7458089730772768, pvalue=8.313751933607014e-32, stderr=0.04412806502907219, intercept_stderr=1.100266644353933)

# %%
# Linear regression on the Northern hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Humidity"]
# call the function
plot_linear_regression(x_values, y_values, "Linear Regression on the Northern Hemisphere \
                        for % Humidity","% Humidity",(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Cloudiness"]
# call the function
plot_linear_regression(x_values, y_values, "Linear Regression on the Northern Hemisphere \
                        for % Cloudiness","% Cloudiness",(40,40))

# %%
# checking the values of r and p (northern Hemisphere)
linregress(x_values,y_values)
# Out:
# LinregressResult(slope=0.015661808460363014, intercept=60.16560475724389, rvalue=0.008412972912527477, pvalue=0.8718712558338835, stderr=0.09704052525782342, intercept_stderr=4.233015517171411)

# %%
# Linear regression on the Southern hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Cloudiness"]
# call the function
plot_linear_regression(x_values, y_values, "Linear Regression on the Southern Hemisphere \
                        for % Cloudiness","% Cloudiness",(-40,40))

# %%
# checking the values of r and p (Southern Hemisphere)
linregress(x_values,y_values)
# Out:
# LinregressResult(slope=0.3680352131137167, intercept=56.8127482202084, rvalue=0.13120575916057844, pvalue=0.086230778110156, stderr=0.21327565513915736, intercept_stderr=5.317706299783368)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
