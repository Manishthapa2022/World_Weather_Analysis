# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longtitude combinations.
lats=np.random.uniform(-90,90, size=1500)
lngs=np.random.uniform(-180,180,size=1500)
lat_lngs=zip(lats, lngs)
coordinates=list(lat_lngs)

# %%
from citipy import citipy

# %%
# generate a list for holding the cities
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# # Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %%
# import the time library and the datetime module from the datetime library
import time
from datetime import datetime
# import the API key
from config import weather_api_key
url= "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key
# city = "Boston"
# query_url = url + "&q=" + city
# print(query_url)

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list 
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count=1
        time.sleep(60)
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count
    record_count+=1
# Run the API request for each of the cities
    try:
        # Parse the json and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list
        city_data.append({"City":city.title(),
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Humidity":city_humidity,
                          "Cloudiness":city_clouds,
                          "Wind Speed":city_wind,
                          "Country":city_country,
                          "Date":city_date})
    # If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | wittingen
# Processing Record 4 of Set 1 | papara
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | mzimba
# Processing Record 9 of Set 1 | maridi
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | banjar
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | marsa matruh
# Processing Record 14 of Set 1 | khandbari
# Processing Record 15 of Set 1 | leningradskiy
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | mehamn
# Processing Record 18 of Set 1 | price
# Processing Record 19 of Set 1 | sawakin
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | tomatlan
# Processing Record 22 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 1 | morehead
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | los llanos de aridane
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | byron bay
# Processing Record 32 of Set 1 | port lincoln
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | sao joao da barra
# Processing Record 36 of Set 1 | saint-pierre
# Processing Record 37 of Set 1 | muzquiz
# City not found. Skipping...
# Processing Record 38 of Set 1 | collie
# Processing Record 39 of Set 1 | araouane
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | champerico
# Processing Record 43 of Set 1 | lorengau
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | fuyu
# Processing Record 46 of Set 1 | tilichiki
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | kutum
# Processing Record 1 of Set 2 | padang
# Processing Record 2 of Set 2 | qaqortoq
# Processing Record 3 of Set 2 | san quintin
# Processing Record 4 of Set 2 | sinnamary
# Processing Record 5 of Set 2 | tarauaca
# Processing Record 6 of Set 2 | telimele
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | beinamar
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | alofi
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | alice springs
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | ponta delgada
# Processing Record 21 of Set 2 | rio verde de mato grosso
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | mizdah
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | pimenta bueno
# Processing Record 27 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | ulaangom
# Processing Record 30 of Set 2 | genhe
# Processing Record 31 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 2 | lima
# Processing Record 33 of Set 2 | lyuban
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | susanville
# Processing Record 37 of Set 2 | hambantota
# Processing Record 38 of Set 2 | inverell
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | sassandra
# Processing Record 41 of Set 2 | aguimes
# Processing Record 42 of Set 2 | salalah
# Processing Record 43 of Set 2 | dingli
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | sur
# Processing Record 46 of Set 2 | rikitea
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | cockburn town
# Processing Record 50 of Set 2 | deputatskiy
# Processing Record 1 of Set 3 | san jeronimo
# Processing Record 2 of Set 3 | poum
# Processing Record 3 of Set 3 | qarqin
# Processing Record 4 of Set 3 | gizo
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | abu samrah
# Processing Record 7 of Set 3 | ceccano
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | ancud
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | paamiut
# Processing Record 13 of Set 3 | opuwo
# Processing Record 14 of Set 3 | kanchanaburi
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | faanui
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | verkhoyansk
# Processing Record 19 of Set 3 | pangai
# Processing Record 20 of Set 3 | norman wells
# Processing Record 21 of Set 3 | vestmannaeyjar
# Processing Record 22 of Set 3 | amozoc
# City not found. Skipping...
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | lampang
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | altus
# Processing Record 27 of Set 3 | korla
# Processing Record 28 of Set 3 | constantine
# Processing Record 29 of Set 3 | anzhero-sudzhensk
# Processing Record 30 of Set 3 | mayumba
# Processing Record 31 of Set 3 | olenegorsk
# Processing Record 32 of Set 3 | egvekinot
# Processing Record 33 of Set 3 | key west
# Processing Record 34 of Set 3 | batagay
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | quarai
# Processing Record 37 of Set 3 | flin flon
# Processing Record 38 of Set 3 | tiarei
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | ashland
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | port hedland
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | bela
# Processing Record 46 of Set 3 | chauk
# Processing Record 47 of Set 3 | chumikan
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | canton
# Processing Record 50 of Set 3 | kasama
# Processing Record 1 of Set 4 | mimongo
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | mataura
# Processing Record 4 of Set 4 | sandwick
# Processing Record 5 of Set 4 | igatpuri
# Processing Record 6 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 8 of Set 4 | lasa
# Processing Record 9 of Set 4 | miles city
# Processing Record 10 of Set 4 | port keats
# Processing Record 11 of Set 4 | cape coast
# Processing Record 12 of Set 4 | kushima
# Processing Record 13 of Set 4 | kulhudhuffushi
# Processing Record 14 of Set 4 | tessalit
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 4 | pakxan
# Processing Record 20 of Set 4 | kidal
# Processing Record 21 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 4 | san juan
# Processing Record 23 of Set 4 | isla vista
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | maragogi
# Processing Record 27 of Set 4 | kalmar
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | nakama
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | santa isabel do rio negro
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | chara
# Processing Record 35 of Set 4 | wichita falls
# Processing Record 36 of Set 4 | aykhal
# Processing Record 37 of Set 4 | kasongo-lunda
# Processing Record 38 of Set 4 | angra
# City not found. Skipping...
# Processing Record 39 of Set 4 | victoria
# Processing Record 40 of Set 4 | muscat
# Processing Record 41 of Set 4 | muisne
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | hammerfest
# Processing Record 44 of Set 4 | cabo san lucas
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | rio gallegos
# Processing Record 49 of Set 4 | hasaki
# Processing Record 50 of Set 4 | fonte boa
# Processing Record 1 of Set 5 | uige
# Processing Record 2 of Set 5 | port alfred
# Processing Record 3 of Set 5 | mollendo
# Processing Record 4 of Set 5 | iracoubo
# Processing Record 5 of Set 5 | khandyga
# Processing Record 6 of Set 5 | mindelo
# Processing Record 7 of Set 5 | jaipur hat
# City not found. Skipping...
# Processing Record 8 of Set 5 | georgetown
# Processing Record 9 of Set 5 | khor
# Processing Record 10 of Set 5 | halifax
# Processing Record 11 of Set 5 | kemin
# Processing Record 12 of Set 5 | makakilo city
# Processing Record 13 of Set 5 | lat yao
# Processing Record 14 of Set 5 | ambulu
# Processing Record 15 of Set 5 | butaritari
# Processing Record 16 of Set 5 | bandarbeyla
# Processing Record 17 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | xining
# Processing Record 20 of Set 5 | beaumont
# Processing Record 21 of Set 5 | sao filipe
# Processing Record 22 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | gusau
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | biak
# Processing Record 26 of Set 5 | la palma
# Processing Record 27 of Set 5 | luwuk
# Processing Record 28 of Set 5 | fairview
# Processing Record 29 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 5 | muroto
# Processing Record 31 of Set 5 | andenes
# Processing Record 32 of Set 5 | republic
# Processing Record 33 of Set 5 | stokmarknes
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | moss vale
# Processing Record 37 of Set 5 | lagos
# Processing Record 38 of Set 5 | lagoa
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | tukrah
# Processing Record 41 of Set 5 | yatou
# Processing Record 42 of Set 5 | mayo
# Processing Record 43 of Set 5 | ajdabiya
# Processing Record 44 of Set 5 | almaty
# Processing Record 45 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 5 | buin
# Processing Record 47 of Set 5 | turukhansk
# Processing Record 48 of Set 5 | tazovskiy
# Processing Record 49 of Set 5 | avera
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | burica
# City not found. Skipping...
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | sorong
# Processing Record 4 of Set 6 | grand-lahou
# Processing Record 5 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 6 | bure
# Processing Record 7 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 6 | kahului
# Processing Record 9 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 6 | arman
# Processing Record 11 of Set 6 | teya
# Processing Record 12 of Set 6 | warwick
# Processing Record 13 of Set 6 | lincoln
# Processing Record 14 of Set 6 | san patricio
# Processing Record 15 of Set 6 | lebu
# Processing Record 16 of Set 6 | matay
# Processing Record 17 of Set 6 | energetik
# Processing Record 18 of Set 6 | cayenne
# Processing Record 19 of Set 6 | nanakuli
# Processing Record 20 of Set 6 | tasiilaq
# Processing Record 21 of Set 6 | ternate
# Processing Record 22 of Set 6 | moerai
# Processing Record 23 of Set 6 | oranjestad
# Processing Record 24 of Set 6 | niort
# Processing Record 25 of Set 6 | mezen
# Processing Record 26 of Set 6 | canta
# Processing Record 27 of Set 6 | qaanaaq
# Processing Record 28 of Set 6 | ixtapa
# Processing Record 29 of Set 6 | arraial do cabo
# Processing Record 30 of Set 6 | guozhen
# Processing Record 31 of Set 6 | nantucket
# Processing Record 32 of Set 6 | joigny
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | plattsburgh
# Processing Record 36 of Set 6 | touros
# Processing Record 37 of Set 6 | kruisfontein
# Processing Record 38 of Set 6 | vizinga
# Processing Record 39 of Set 6 | montrose
# Processing Record 40 of Set 6 | katsuura
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | dingle
# Processing Record 43 of Set 6 | kaseda
# Processing Record 44 of Set 6 | maniitsoq
# Processing Record 45 of Set 6 | gillette
# Processing Record 46 of Set 6 | kem
# Processing Record 47 of Set 6 | atka
# City not found. Skipping...
# Processing Record 48 of Set 6 | ziarat
# Processing Record 49 of Set 6 | mahaicony
# City not found. Skipping...
# Processing Record 50 of Set 6 | nanortalik
# Processing Record 1 of Set 7 | araguari
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | quibdo
# Processing Record 5 of Set 7 | borgarnes
# Processing Record 6 of Set 7 | tunxi
# City not found. Skipping...
# Processing Record 7 of Set 7 | burnie
# Processing Record 8 of Set 7 | ambilobe
# Processing Record 9 of Set 7 | jimenez
# Processing Record 10 of Set 7 | thinadhoo
# Processing Record 11 of Set 7 | hovd
# Processing Record 12 of Set 7 | margherita di savoia
# Processing Record 13 of Set 7 | meulaboh
# Processing Record 14 of Set 7 | itarema
# Processing Record 15 of Set 7 | megion
# Processing Record 16 of Set 7 | morro bay
# Processing Record 17 of Set 7 | omboue
# Processing Record 18 of Set 7 | bengkulu
# Processing Record 19 of Set 7 | skibbereen
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | queenstown
# Processing Record 23 of Set 7 | casa grande
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | kibala
# Processing Record 26 of Set 7 | plettenberg bay
# Processing Record 27 of Set 7 | lewisporte
# Processing Record 28 of Set 7 | north platte
# Processing Record 29 of Set 7 | zhaozhou
# Processing Record 30 of Set 7 | namatanai
# Processing Record 31 of Set 7 | yeniseysk
# Processing Record 32 of Set 7 | wexford
# Processing Record 33 of Set 7 | bonfim
# Processing Record 34 of Set 7 | gashua
# Processing Record 35 of Set 7 | mporokoso
# Processing Record 36 of Set 7 | marawi
# Processing Record 37 of Set 7 | viedma
# Processing Record 38 of Set 7 | tawau
# Processing Record 39 of Set 7 | margate
# Processing Record 40 of Set 7 | mamou
# Processing Record 41 of Set 7 | chulym
# Processing Record 42 of Set 7 | cortez
# Processing Record 43 of Set 7 | cherskiy
# Processing Record 44 of Set 7 | ayr
# Processing Record 45 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 7 | fairbanks
# Processing Record 47 of Set 7 | souris
# Processing Record 48 of Set 7 | saurimo
# Processing Record 49 of Set 7 | sipe sipe
# Processing Record 50 of Set 7 | emerald
# Processing Record 1 of Set 8 | lhokseumawe
# Processing Record 2 of Set 8 | chokurdakh
# Processing Record 3 of Set 8 | hirara
# Processing Record 4 of Set 8 | grindavik
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 8 | asau
# Processing Record 8 of Set 8 | marabba
# Processing Record 9 of Set 8 | shamkhal
# Processing Record 10 of Set 8 | council bluffs
# Processing Record 11 of Set 8 | ust-nera
# Processing Record 12 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 8 | faya
# Processing Record 14 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 8 | skjervoy
# Processing Record 16 of Set 8 | aksarayskiy
# Processing Record 17 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 8 | owatonna
# Processing Record 19 of Set 8 | berdigestyakh
# Processing Record 20 of Set 8 | shanhetun
# Processing Record 21 of Set 8 | lebedinyy
# Processing Record 22 of Set 8 | boddam
# Processing Record 23 of Set 8 | bandundu
# Processing Record 24 of Set 8 | gagra
# Processing Record 25 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | pangnirtung
# Processing Record 27 of Set 8 | diapaga
# Processing Record 28 of Set 8 | zhigansk
# Processing Record 29 of Set 8 | takhatpur
# Processing Record 30 of Set 8 | leander
# Processing Record 31 of Set 8 | vigrestad
# Processing Record 32 of Set 8 | saint george
# Processing Record 33 of Set 8 | bograd
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | nelson bay
# Processing Record 36 of Set 8 | broumov
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | skelleftea
# Processing Record 39 of Set 8 | kamenka
# Processing Record 40 of Set 8 | mamallapuram
# Processing Record 41 of Set 8 | rhyl
# Processing Record 42 of Set 8 | vardo
# Processing Record 43 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 44 of Set 8 | vao
# Processing Record 45 of Set 8 | poltavka
# Processing Record 46 of Set 8 | port hardy
# Processing Record 47 of Set 8 | aitape
# Processing Record 48 of Set 8 | quelimane
# Processing Record 49 of Set 8 | takanabe
# Processing Record 50 of Set 8 | lucapa
# Processing Record 1 of Set 9 | along
# Processing Record 2 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 9 | ahipara
# Processing Record 4 of Set 9 | awbari
# Processing Record 5 of Set 9 | kiama
# Processing Record 6 of Set 9 | san vicente
# Processing Record 7 of Set 9 | tautira
# Processing Record 8 of Set 9 | pisco
# Processing Record 9 of Set 9 | lalibela
# Processing Record 10 of Set 9 | slatina
# Processing Record 11 of Set 9 | rafai
# Processing Record 12 of Set 9 | bathsheba
# Processing Record 13 of Set 9 | sumbe
# Processing Record 14 of Set 9 | novopskov
# Processing Record 15 of Set 9 | altamira
# Processing Record 16 of Set 9 | antofagasta
# Processing Record 17 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 9 | suoyarvi
# Processing Record 19 of Set 9 | shubarshi
# Processing Record 20 of Set 9 | souillac
# Processing Record 21 of Set 9 | vostok
# Processing Record 22 of Set 9 | gwadar
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | bolnisi
# Processing Record 25 of Set 9 | amapa
# Processing Record 26 of Set 9 | orange
# Processing Record 27 of Set 9 | bukachacha
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | abaza
# Processing Record 30 of Set 9 | santa luzia
# Processing Record 31 of Set 9 | porto novo
# Processing Record 32 of Set 9 | varva
# Processing Record 33 of Set 9 | yeppoon
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | changde
# Processing Record 36 of Set 9 | japura
# Processing Record 37 of Set 9 | fukue
# Processing Record 38 of Set 9 | adre
# Processing Record 39 of Set 9 | trairi
# Processing Record 40 of Set 9 | aswan
# Processing Record 41 of Set 9 | flinders
# Processing Record 42 of Set 9 | vestmanna
# Processing Record 43 of Set 9 | saint-philippe
# Processing Record 44 of Set 9 | dixon
# Processing Record 45 of Set 9 | diphu
# Processing Record 46 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 9 | boden
# Processing Record 48 of Set 9 | ostrovnoy
# Processing Record 49 of Set 9 | jackson
# Processing Record 50 of Set 9 | urumqi
# Processing Record 1 of Set 10 | san cristobal
# Processing Record 2 of Set 10 | bonthe
# Processing Record 3 of Set 10 | santa rosa
# Processing Record 4 of Set 10 | adrar
# Processing Record 5 of Set 10 | wajima
# Processing Record 6 of Set 10 | kloulklubed
# Processing Record 7 of Set 10 | siloam springs
# Processing Record 8 of Set 10 | kenai
# Processing Record 9 of Set 10 | babati
# Processing Record 10 of Set 10 | kempsey
# Processing Record 11 of Set 10 | delta del tigre
# Processing Record 12 of Set 10 | bosaso
# Processing Record 13 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 15 of Set 10 | pahrump
# Processing Record 16 of Set 10 | belen
# Processing Record 17 of Set 10 | broome
# Processing Record 18 of Set 10 | port moresby
# Processing Record 19 of Set 10 | ler
# Processing Record 20 of Set 10 | malakal
# Processing Record 21 of Set 10 | awjilah
# Processing Record 22 of Set 10 | krasnoselkup
# Processing Record 23 of Set 10 | parana
# Processing Record 24 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 25 of Set 10 | burns lake
# Processing Record 26 of Set 10 | sorland
# Processing Record 27 of Set 10 | mutis
# Processing Record 28 of Set 10 | westport
# Processing Record 29 of Set 10 | chimbote
# Processing Record 30 of Set 10 | ulladulla
# Processing Record 31 of Set 10 | aleysk
# Processing Record 32 of Set 10 | alvand
# Processing Record 33 of Set 10 | huarmey
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | san rafael
# Processing Record 36 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | gazanjyk
# Processing Record 38 of Set 10 | pimenteiras
# Processing Record 39 of Set 10 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 40 of Set 10 | yakeshi
# Processing Record 41 of Set 10 | loudi
# Processing Record 42 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 10 | provideniya
# Processing Record 44 of Set 10 | sola
# Processing Record 45 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 10 | bambous virieux
# Processing Record 47 of Set 10 | manama
# Processing Record 48 of Set 10 | puri
# Processing Record 49 of Set 10 | olga
# Processing Record 50 of Set 10 | sao jose da coroa grande
# Processing Record 1 of Set 11 | tsiroanomandidy
# Processing Record 2 of Set 11 | ende
# Processing Record 3 of Set 11 | port blair
# Processing Record 4 of Set 11 | ucluelet
# Processing Record 5 of Set 11 | usta muhammad
# Processing Record 6 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 11 | yatsushiro
# Processing Record 8 of Set 11 | haines junction
# Processing Record 9 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 11 | taoudenni
# Processing Record 11 of Set 11 | ilulissat
# Processing Record 12 of Set 11 | dong hoi
# Processing Record 13 of Set 11 | taltal
# Processing Record 14 of Set 11 | kathu
# Processing Record 15 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 16 of Set 11 | hofn
# Processing Record 17 of Set 11 | mitchelstown
# Processing Record 18 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 11 | nizhniy baskunchak
# Processing Record 20 of Set 11 | tahta
# Processing Record 21 of Set 11 | imbituba
# Processing Record 22 of Set 11 | bozhou
# Processing Record 23 of Set 11 | capim grosso
# Processing Record 24 of Set 11 | inuvik
# Processing Record 25 of Set 11 | matagami
# Processing Record 26 of Set 11 | kudahuvadhoo
# Processing Record 27 of Set 11 | the valley
# Processing Record 28 of Set 11 | atambua
# Processing Record 29 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 11 | vaitape
# Processing Record 31 of Set 11 | kenora
# Processing Record 32 of Set 11 | isangel
# Processing Record 33 of Set 11 | tairua
# Processing Record 34 of Set 11 | portland
# Processing Record 35 of Set 11 | xucheng
# Processing Record 36 of Set 11 | baishishan
# Processing Record 37 of Set 11 | puerto narino
# Processing Record 38 of Set 11 | tornio
# Processing Record 39 of Set 11 | codrington
# Processing Record 40 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 11 | camacha
# Processing Record 42 of Set 11 | lumberton
# Processing Record 43 of Set 11 | hami
# Processing Record 44 of Set 11 | calama
# Processing Record 45 of Set 11 | indramayu
# Processing Record 46 of Set 11 | batayurt
# Processing Record 47 of Set 11 | sarishabari
# Processing Record 48 of Set 11 | tambopata
# Processing Record 49 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 11 | riosucio
# Processing Record 1 of Set 12 | seydi
# Processing Record 2 of Set 12 | puerto del rosario
# Processing Record 3 of Set 12 | bose
# Processing Record 4 of Set 12 | soyo
# Processing Record 5 of Set 12 | najran
# Processing Record 6 of Set 12 | almenara
# Processing Record 7 of Set 12 | topeka
# Processing Record 8 of Set 12 | goderich
# Processing Record 9 of Set 12 | bubaque
# Processing Record 10 of Set 12 | bellevue
# Processing Record 11 of Set 12 | caohai
# Processing Record 12 of Set 12 | prince rupert
# Processing Record 13 of Set 12 | sicuani
# Processing Record 14 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 15 of Set 12 | bardiyah
# Processing Record 16 of Set 12 | minot
# Processing Record 17 of Set 12 | sarankhola
# Processing Record 18 of Set 12 | nautla
# Processing Record 19 of Set 12 | santiago del estero
# Processing Record 20 of Set 12 | mirnyy
# Processing Record 21 of Set 12 | malpe
# Processing Record 22 of Set 12 | nagorsk
# Processing Record 23 of Set 12 | almunecar
# Processing Record 24 of Set 12 | kalmunai
# Processing Record 25 of Set 12 | kattivakkam
# Processing Record 26 of Set 12 | buraydah
# Processing Record 27 of Set 12 | goedereede
# Processing Record 28 of Set 12 | camocim
# Processing Record 29 of Set 12 | shenjiamen
# Processing Record 30 of Set 12 | bodden town
# Processing Record 31 of Set 12 | rundu
# Processing Record 32 of Set 12 | coihaique
# Processing Record 33 of Set 12 | tirschenreuth
# Processing Record 34 of Set 12 | zhanaozen
# Processing Record 35 of Set 12 | barra do corda
# Processing Record 36 of Set 12 | le port
# Processing Record 37 of Set 12 | aloleng
# Processing Record 38 of Set 12 | olinda
# Processing Record 39 of Set 12 | vilyuysk
# Processing Record 40 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 41 of Set 12 | talaya
# Processing Record 42 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 12 | goundi
# Processing Record 44 of Set 12 | ewa beach
# Processing Record 45 of Set 12 | warrnambool
# Processing Record 46 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 12 | bilma
# Processing Record 48 of Set 12 | puerto colombia
# Processing Record 49 of Set 12 | tocopilla
# Processing Record 50 of Set 12 | eyl
# Processing Record 1 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 13 | vernon
# Processing Record 3 of Set 13 | diebougou
# Processing Record 4 of Set 13 | mabaruma
# Processing Record 5 of Set 13 | maceio
# Processing Record 6 of Set 13 | jalu
# Processing Record 7 of Set 13 | sayat
# Processing Record 8 of Set 13 | san javier
# Processing Record 9 of Set 13 | sopelana
# Processing Record 10 of Set 13 | balagansk
# Processing Record 11 of Set 13 | vitim
# Processing Record 12 of Set 13 | teberda
# Processing Record 13 of Set 13 | mier
# Processing Record 14 of Set 13 | abu zabad
# Processing Record 15 of Set 13 | baykit
# Processing Record 16 of Set 13 | pulandian
# Processing Record 17 of Set 13 | tahara
# Processing Record 18 of Set 13 | bac lieu
# Processing Record 19 of Set 13 | olafsvik
# Processing Record 20 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 13 | sanawad
# Processing Record 22 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 13 | thetford mines
# Processing Record 24 of Set 13 | yako
# Processing Record 25 of Set 13 | svetlyy
# Processing Record 26 of Set 13 | micheweni
# Processing Record 27 of Set 13 | verkhnetulomskiy
# Processing Record 28 of Set 13 | sobolevo
# Processing Record 29 of Set 13 | okato
# Processing Record 30 of Set 13 | longyearbyen
# Processing Record 31 of Set 13 | asamankese
# Processing Record 32 of Set 13 | caucaia
# Processing Record 33 of Set 13 | puerto cabezas
# Processing Record 34 of Set 13 | nouakchott
# Processing Record 35 of Set 13 | tawang
# Processing Record 36 of Set 13 | port-gentil
# Processing Record 37 of Set 13 | catuday
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
len(city_data)
# Out:
# 573

# %%
#  Convert the array of dictionaries to a Pandas DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Castro -24.7911  -50.0119     70.50        61           0        3.22
# 1    Ushuaia -54.8000  -68.3000     56.86        44          20        8.05
# 2  Wittingen  52.7269   10.7361     55.40        72         100        8.52
# 3     Papara  -3.9839  -38.7273     81.00        51          70        7.63
# 4      Vaini -21.2000 -175.2000     77.16        88          40        3.44
# 5  Busselton -33.6500  115.3333     56.66        78          97       16.49
# 6     Mzimba -11.9000   33.6000     66.43        41          18       10.89
# 7     Maridi   4.9158   29.4742     66.99        95         100        1.39
# 8      Airai  -8.9266  125.4092     61.41        87          99        1.54
# 9     Banjar  -8.1900  114.9675     76.39        91          63        6.26
#
#   Country                 Date
# 0      BR  2022-10-04 19:57:42
# 1      AR  2022-10-04 19:57:43
# 2      DE  2022-10-04 19:57:43
# 3      BR  2022-10-04 19:57:44
# 4      TO  2022-10-04 19:57:44
# 5      AU  2022-10-04 19:57:45
# 6      MW  2022-10-04 19:57:45
# 7      SS  2022-10-04 19:57:46
# 8      TL  2022-10-04 19:57:47
# 9      ID  2022-10-04 19:57:48

# %%
# reorder the column so that the dataframe reads different
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0     Castro      BR  2022-10-04 19:57:42 -24.7911  -50.0119     70.50
# 1    Ushuaia      AR  2022-10-04 19:57:43 -54.8000  -68.3000     56.86
# 2  Wittingen      DE  2022-10-04 19:57:43  52.7269   10.7361     55.40
# 3     Papara      BR  2022-10-04 19:57:44  -3.9839  -38.7273     81.00
# 4      Vaini      TO  2022-10-04 19:57:44 -21.2000 -175.2000     77.16
# 5  Busselton      AU  2022-10-04 19:57:45 -33.6500  115.3333     56.66
# 6     Mzimba      MW  2022-10-04 19:57:45 -11.9000   33.6000     66.43
# 7     Maridi      SS  2022-10-04 19:57:46   4.9158   29.4742     66.99
# 8      Airai      TL  2022-10-04 19:57:47  -8.9266  125.4092     61.41
# 9     Banjar      ID  2022-10-04 19:57:48  -8.1900  114.9675     76.39
#
#    Humidity  Cloudiness  Wind Speed
# 0        61           0        3.22
# 1        44          20        8.05
# 2        72         100        8.52
# 3        51          70        7.63
# 4        88          40        3.44
# 5        78          97       16.49
# 6        41          18       10.89
# 7        95         100        1.39
# 8        87          99        1.54
# 9        91          63        6.26

# %%
# Create a output csv file
output_data_file="weather_data/cities.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relelvant feilds from the DataFrame for plotting
lats=city_data_df["Lat"]
max_temps=city_data_df["Max Temp"]
humidity=city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# import time modulle 
# Build the scatter plot for latitude vs max ttemperature
plt.scatter(lats,
           max_temps,
           edgecolors="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")
# incorporate other graph properties
plt.title(f"City Latitude vs.Max Temperature" + time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
          
# Save figure
plt.savefig("weather_data/Fig1.png")
          
# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
