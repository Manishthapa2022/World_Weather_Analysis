# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates =list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
     # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_description=city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
         # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')    
        # Append the city information into the city_data list
        city_data.append({"City":city.title(),
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Current Description":city_description,
                          "Humidity":city_humidity,
                          "Cloudiness":city_clouds,
                          "Wind Speed":city_wind,
                          "Country":city_country,
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | santa maria
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | samsun
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 1 | kathu
# Processing Record 10 of Set 1 | caravelas
# Processing Record 11 of Set 1 | poum
# Processing Record 12 of Set 1 | lewistown
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | nybro
# Processing Record 15 of Set 1 | egvekinot
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | deputatskiy
# Processing Record 24 of Set 1 | vardo
# Processing Record 25 of Set 1 | novikovo
# Processing Record 26 of Set 1 | xichang
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | abrego
# Processing Record 30 of Set 1 | roma
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | tsentralnyy
# City not found. Skipping...
# Processing Record 33 of Set 1 | soure
# Processing Record 34 of Set 1 | nome
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | nanchong
# Processing Record 38 of Set 1 | puri
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | cayenne
# Processing Record 43 of Set 1 | kollumerland
# City not found. Skipping...
# Processing Record 44 of Set 1 | zyryanka
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | shulan
# Processing Record 47 of Set 1 | namatanai
# Processing Record 48 of Set 1 | aksu
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 2 | muros
# Processing Record 2 of Set 2 | itacarambi
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | yerbogachen
# Processing Record 5 of Set 2 | touros
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | sao joao da barra
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | port hardy
# Processing Record 10 of Set 2 | homer
# Processing Record 11 of Set 2 | taltal
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 2 | port augusta
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | jardim
# Processing Record 17 of Set 2 | padang
# Processing Record 18 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-denis
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | keuruu
# Processing Record 25 of Set 2 | teguldet
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | kruisfontein
# Processing Record 28 of Set 2 | kainantu
# Processing Record 29 of Set 2 | goderich
# Processing Record 30 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 2 | shingu
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | alekseyevka
# Processing Record 36 of Set 2 | broome
# Processing Record 37 of Set 2 | erenhot
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | oxapampa
# Processing Record 40 of Set 2 | tanout
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | salamiyah
# Processing Record 44 of Set 2 | kokstad
# Processing Record 45 of Set 2 | acapulco
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | kungurtug
# Processing Record 49 of Set 2 | labuhan
# Processing Record 50 of Set 2 | bambui
# Processing Record 1 of Set 3 | cabedelo
# Processing Record 2 of Set 3 | flin flon
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | muhos
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | zhanakorgan
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | karasjok
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | adrar
# Processing Record 13 of Set 3 | fountain
# Processing Record 14 of Set 3 | kumano
# Processing Record 15 of Set 3 | kavieng
# Processing Record 16 of Set 3 | aykhal
# Processing Record 17 of Set 3 | marsh harbour
# Processing Record 18 of Set 3 | naklo nad notecia
# Processing Record 19 of Set 3 | barcelos
# Processing Record 20 of Set 3 | sisimiut
# Processing Record 21 of Set 3 | bondoukou
# Processing Record 22 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 3 | barranca
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | varnavino
# Processing Record 27 of Set 3 | aranda de duero
# Processing Record 28 of Set 3 | baykit
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 3 | port-gentil
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | makakilo city
# Processing Record 35 of Set 3 | mogadishu
# Processing Record 36 of Set 3 | karratha
# Processing Record 37 of Set 3 | tucurui
# Processing Record 38 of Set 3 | saint-francois
# Processing Record 39 of Set 3 | plettenberg bay
# Processing Record 40 of Set 3 | epe
# Processing Record 41 of Set 3 | surt
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | byron bay
# Processing Record 44 of Set 3 | nagato
# Processing Record 45 of Set 3 | yumen
# Processing Record 46 of Set 3 | vao
# Processing Record 47 of Set 3 | fukue
# Processing Record 48 of Set 3 | paamiut
# Processing Record 49 of Set 3 | paratinga
# Processing Record 50 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 4 | okha
# Processing Record 2 of Set 4 | rosita
# Processing Record 3 of Set 4 | itarema
# Processing Record 4 of Set 4 | kolondieba
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | chernyakhovsk
# Processing Record 7 of Set 4 | abu kamal
# Processing Record 8 of Set 4 | erzin
# Processing Record 9 of Set 4 | trofors
# Processing Record 10 of Set 4 | mosquera
# Processing Record 11 of Set 4 | uitenhage
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | puerto del rosario
# Processing Record 14 of Set 4 | semporna
# Processing Record 15 of Set 4 | amapa
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 4 | barrow
# Processing Record 19 of Set 4 | guatire
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | college
# Processing Record 22 of Set 4 | shenzhen
# Processing Record 23 of Set 4 | yurginskoye
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | gornopravdinsk
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | atuona
# Processing Record 28 of Set 4 | kutum
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | lusambo
# Processing Record 31 of Set 4 | sur
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | kamloops
# Processing Record 34 of Set 4 | puerto asis
# Processing Record 35 of Set 4 | luderitz
# Processing Record 36 of Set 4 | asfi
# Processing Record 37 of Set 4 | vite
# Processing Record 38 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 39 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 4 | krasnoselkup
# Processing Record 41 of Set 4 | chicama
# Processing Record 42 of Set 4 | mocuba
# Processing Record 43 of Set 4 | afua
# Processing Record 44 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 4 | brazzaville
# Processing Record 46 of Set 4 | akureyri
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | rorvik
# Processing Record 49 of Set 4 | roros
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | mandalgovi
# Processing Record 2 of Set 5 | brookhaven
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 5 of Set 5 | naze
# Processing Record 6 of Set 5 | mehamn
# Processing Record 7 of Set 5 | kang
# Processing Record 8 of Set 5 | gravdal
# Processing Record 9 of Set 5 | kapustin yar
# Processing Record 10 of Set 5 | neosho
# Processing Record 11 of Set 5 | thompson
# Processing Record 12 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | puerto penasco
# Processing Record 15 of Set 5 | norman wells
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | vestmannaeyjar
# Processing Record 18 of Set 5 | katherine
# Processing Record 19 of Set 5 | meulaboh
# Processing Record 20 of Set 5 | hammerfest
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | olafsvik
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | bereda
# Processing Record 27 of Set 5 | tiksi
# Processing Record 28 of Set 5 | aljezur
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | singkang
# Processing Record 31 of Set 5 | abu samrah
# Processing Record 32 of Set 5 | mount isa
# Processing Record 33 of Set 5 | ryotsu
# Processing Record 34 of Set 5 | mozarlandia
# Processing Record 35 of Set 5 | hualmay
# Processing Record 36 of Set 5 | kazachinskoye
# Processing Record 37 of Set 5 | rocha
# Processing Record 38 of Set 5 | bilma
# Processing Record 39 of Set 5 | newport
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | thongwa
# Processing Record 42 of Set 5 | tasiilaq
# Processing Record 43 of Set 5 | christchurch
# Processing Record 44 of Set 5 | okhtyrka
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | aswan
# Processing Record 47 of Set 5 | filadelfia
# Processing Record 48 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 49 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 5 | imbituba
# Processing Record 1 of Set 6 | chifeng
# Processing Record 2 of Set 6 | burnham
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | rolla
# Processing Record 5 of Set 6 | half moon bay
# Processing Record 6 of Set 6 | mumford
# Processing Record 7 of Set 6 | nabire
# Processing Record 8 of Set 6 | east london
# Processing Record 9 of Set 6 | moron
# Processing Record 10 of Set 6 | tornio
# Processing Record 11 of Set 6 | lacdayan
# Processing Record 12 of Set 6 | sinegorye
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | vaitape
# Processing Record 15 of Set 6 | kabalo
# Processing Record 16 of Set 6 | esna
# Processing Record 17 of Set 6 | severo-kurilsk
# Processing Record 18 of Set 6 | chudniv
# Processing Record 19 of Set 6 | ouallam
# Processing Record 20 of Set 6 | los llanos de aridane
# Processing Record 21 of Set 6 | matagami
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | khomeyn
# Processing Record 24 of Set 6 | qui nhon
# Processing Record 25 of Set 6 | north bend
# Processing Record 26 of Set 6 | zheleznodorozhnyy
# Processing Record 27 of Set 6 | pedernales
# Processing Record 28 of Set 6 | mahebourg
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | lubao
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | palana
# Processing Record 34 of Set 6 | lengshuijiang
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | trinidad
# Processing Record 38 of Set 6 | kathmandu
# Processing Record 39 of Set 6 | itapage
# Processing Record 40 of Set 6 | fort nelson
# Processing Record 41 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 6 | pacifica
# Processing Record 43 of Set 6 | moose factory
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | maceio
# Processing Record 47 of Set 6 | chadiza
# Processing Record 48 of Set 6 | helong
# Processing Record 49 of Set 6 | gazojak
# Processing Record 50 of Set 6 | pochutla
# Processing Record 1 of Set 7 | neiafu
# Processing Record 2 of Set 7 | los mochis
# Processing Record 3 of Set 7 | clyde river
# Processing Record 4 of Set 7 | aklavik
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | oktyabrskoye
# Processing Record 7 of Set 7 | biak
# Processing Record 8 of Set 7 | clifton springs
# Processing Record 9 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 7 | redcar
# Processing Record 11 of Set 7 | gizo
# Processing Record 12 of Set 7 | cidreira
# Processing Record 13 of Set 7 | fuerte olimpo
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 7 | takaka
# Processing Record 17 of Set 7 | souillac
# Processing Record 18 of Set 7 | vanavara
# Processing Record 19 of Set 7 | ballina
# Processing Record 20 of Set 7 | talesh
# City not found. Skipping...
# Processing Record 21 of Set 7 | armidale
# Processing Record 22 of Set 7 | nishihara
# Processing Record 23 of Set 7 | poretskoye
# Processing Record 24 of Set 7 | kasongo-lunda
# Processing Record 25 of Set 7 | port macquarie
# Processing Record 26 of Set 7 | ketchikan
# Processing Record 27 of Set 7 | presidente epitacio
# Processing Record 28 of Set 7 | daru
# Processing Record 29 of Set 7 | khatanga
# Processing Record 30 of Set 7 | fuling
# Processing Record 31 of Set 7 | rantepao
# Processing Record 32 of Set 7 | couva
# Processing Record 33 of Set 7 | tortoli
# Processing Record 34 of Set 7 | harper
# Processing Record 35 of Set 7 | lakatoro
# Processing Record 36 of Set 7 | abbeville
# Processing Record 37 of Set 7 | omboue
# Processing Record 38 of Set 7 | pisco
# Processing Record 39 of Set 7 | tiznit
# Processing Record 40 of Set 7 | puerto madryn
# Processing Record 41 of Set 7 | lensk
# Processing Record 42 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 43 of Set 7 | castro
# Processing Record 44 of Set 7 | wamba
# Processing Record 45 of Set 7 | floro
# Processing Record 46 of Set 7 | rantauprapat
# Processing Record 47 of Set 7 | boguchany
# Processing Record 48 of Set 7 | lermontovka
# Processing Record 49 of Set 7 | murgab
# Processing Record 50 of Set 7 | leningradskiy
# Processing Record 1 of Set 8 | faanui
# Processing Record 2 of Set 8 | kieta
# Processing Record 3 of Set 8 | santa cruz
# Processing Record 4 of Set 8 | natal
# Processing Record 5 of Set 8 | veraval
# Processing Record 6 of Set 8 | ponta delgada
# Processing Record 7 of Set 8 | margate
# Processing Record 8 of Set 8 | persan
# Processing Record 9 of Set 8 | khuzdar
# Processing Record 10 of Set 8 | kumylzhenskaya
# Processing Record 11 of Set 8 | ginda
# Processing Record 12 of Set 8 | avera
# Processing Record 13 of Set 8 | upington
# Processing Record 14 of Set 8 | karmana
# City not found. Skipping...
# Processing Record 15 of Set 8 | kiunga
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | ahipara
# Processing Record 19 of Set 8 | bubaque
# Processing Record 20 of Set 8 | jiazi
# Processing Record 21 of Set 8 | mujiayingzi
# Processing Record 22 of Set 8 | mezen
# Processing Record 23 of Set 8 | gat
# Processing Record 24 of Set 8 | korla
# Processing Record 25 of Set 8 | huilong
# Processing Record 26 of Set 8 | banjar
# Processing Record 27 of Set 8 | sola
# Processing Record 28 of Set 8 | trollhattan
# Processing Record 29 of Set 8 | tura
# Processing Record 30 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 8 | saint-philippe
# Processing Record 32 of Set 8 | liwale
# Processing Record 33 of Set 8 | la grande
# Processing Record 34 of Set 8 | broken hill
# Processing Record 35 of Set 8 | manuk mangkaw
# Processing Record 36 of Set 8 | ruidoso
# Processing Record 37 of Set 8 | henties bay
# Processing Record 38 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 8 | ambanja
# Processing Record 40 of Set 8 | talaya
# Processing Record 41 of Set 8 | olga
# Processing Record 42 of Set 8 | vilhena
# Processing Record 43 of Set 8 | saint anthony
# Processing Record 44 of Set 8 | la brea
# Processing Record 45 of Set 8 | kandrian
# Processing Record 46 of Set 8 | fare
# Processing Record 47 of Set 8 | ambilobe
# Processing Record 48 of Set 8 | foam lake
# Processing Record 49 of Set 8 | malinovskiy
# Processing Record 50 of Set 8 | nikel
# Processing Record 1 of Set 9 | boda
# Processing Record 2 of Set 9 | ostrovnoy
# Processing Record 3 of Set 9 | lixourion
# Processing Record 4 of Set 9 | vila
# Processing Record 5 of Set 9 | atasu
# Processing Record 6 of Set 9 | kemijarvi
# Processing Record 7 of Set 9 | khasan
# Processing Record 8 of Set 9 | ullapool
# Processing Record 9 of Set 9 | skibbereen
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | lasa
# Processing Record 12 of Set 9 | mana
# Processing Record 13 of Set 9 | praia da vitoria
# Processing Record 14 of Set 9 | nuevo progreso
# Processing Record 15 of Set 9 | tamworth
# Processing Record 16 of Set 9 | dongsheng
# Processing Record 17 of Set 9 | yulara
# Processing Record 18 of Set 9 | lagoa
# Processing Record 19 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 21 of Set 9 | qinhuangdao
# Processing Record 22 of Set 9 | garzon
# Processing Record 23 of Set 9 | lock haven
# Processing Record 24 of Set 9 | verkhoyansk
# Processing Record 25 of Set 9 | unity
# Processing Record 26 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 27 of Set 9 | dudinka
# Processing Record 28 of Set 9 | maragogi
# Processing Record 29 of Set 9 | alta floresta
# Processing Record 30 of Set 9 | sakhnovshchyna
# Processing Record 31 of Set 9 | auki
# Processing Record 32 of Set 9 | alofi
# Processing Record 33 of Set 9 | belmonte
# Processing Record 34 of Set 9 | lincoln
# Processing Record 35 of Set 9 | vadinsk
# Processing Record 36 of Set 9 | oranienburg
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | mbigou
# Processing Record 39 of Set 9 | ouesso
# Processing Record 40 of Set 9 | tehri
# Processing Record 41 of Set 9 | owensboro
# Processing Record 42 of Set 9 | acarau
# Processing Record 43 of Set 9 | bantogon
# Processing Record 44 of Set 9 | kelso
# Processing Record 45 of Set 9 | zhangjiakou
# Processing Record 46 of Set 9 | moscow
# Processing Record 47 of Set 9 | valleyview
# Processing Record 48 of Set 9 | torit
# Processing Record 49 of Set 9 | ojinaga
# Processing Record 50 of Set 9 | turukhansk
# Processing Record 1 of Set 10 | laguna
# Processing Record 2 of Set 10 | honiara
# Processing Record 3 of Set 10 | pitimbu
# Processing Record 4 of Set 10 | iqaluit
# Processing Record 5 of Set 10 | aranos
# Processing Record 6 of Set 10 | minuri
# Processing Record 7 of Set 10 | cubuk
# Processing Record 8 of Set 10 | columbus
# Processing Record 9 of Set 10 | djibo
# Processing Record 10 of Set 10 | san policarpo
# Processing Record 11 of Set 10 | sarahan
# Processing Record 12 of Set 10 | peniche
# Processing Record 13 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 10 | malanje
# Processing Record 15 of Set 10 | palmer
# Processing Record 16 of Set 10 | grand forks
# Processing Record 17 of Set 10 | boa vista
# Processing Record 18 of Set 10 | arlit
# Processing Record 19 of Set 10 | sao filipe
# Processing Record 20 of Set 10 | ust-maya
# Processing Record 21 of Set 10 | camana
# Processing Record 22 of Set 10 | waddan
# Processing Record 23 of Set 10 | sabha
# Processing Record 24 of Set 10 | bathsheba
# Processing Record 25 of Set 10 | viedma
# Processing Record 26 of Set 10 | venice
# Processing Record 27 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 10 | manyana
# Processing Record 29 of Set 10 | te anau
# Processing Record 30 of Set 10 | wete
# Processing Record 31 of Set 10 | egra
# Processing Record 32 of Set 10 | bakchar
# Processing Record 33 of Set 10 | camacha
# Processing Record 34 of Set 10 | wexford
# Processing Record 35 of Set 10 | senneterre
# Processing Record 36 of Set 10 | posse
# Processing Record 37 of Set 10 | sungaipenuh
# Processing Record 38 of Set 10 | eregli
# Processing Record 39 of Set 10 | shenjiamen
# Processing Record 40 of Set 10 | nemuro
# Processing Record 41 of Set 10 | barra do corda
# Processing Record 42 of Set 10 | agua verde
# Processing Record 43 of Set 10 | tautira
# Processing Record 44 of Set 10 | torbay
# Processing Record 45 of Set 10 | buraydah
# Processing Record 46 of Set 10 | san ramon
# Processing Record 47 of Set 10 | tsumeb
# Processing Record 48 of Set 10 | cam ranh
# Processing Record 49 of Set 10 | prokhorovka
# Processing Record 50 of Set 10 | carauari
# Processing Record 1 of Set 11 | tilichiki
# Processing Record 2 of Set 11 | arman
# Processing Record 3 of Set 11 | bandarbeyla
# Processing Record 4 of Set 11 | penticton
# Processing Record 5 of Set 11 | benghazi
# Processing Record 6 of Set 11 | ust-kut
# Processing Record 7 of Set 11 | piacabucu
# Processing Record 8 of Set 11 | coolum beach
# Processing Record 9 of Set 11 | kabompo
# Processing Record 10 of Set 11 | autun
# Processing Record 11 of Set 11 | stornoway
# Processing Record 12 of Set 11 | atar
# Processing Record 13 of Set 11 | wajid
# Processing Record 14 of Set 11 | pangnirtung
# Processing Record 15 of Set 11 | ninh binh
# Processing Record 16 of Set 11 | annemasse
# Processing Record 17 of Set 11 | butka
# Processing Record 18 of Set 11 | capinota
# Processing Record 19 of Set 11 | ukmerge
# Processing Record 20 of Set 11 | husavik
# Processing Record 21 of Set 11 | vernon
# Processing Record 22 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 23 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 11 | rincon
# Processing Record 25 of Set 11 | kampene
# Processing Record 26 of Set 11 | ayagoz
# Processing Record 27 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 11 | salalah
# Processing Record 30 of Set 11 | chapais
# Processing Record 31 of Set 11 | oktyabrskiy
# Processing Record 32 of Set 11 | high prairie
# Processing Record 33 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 11 | inongo
# Processing Record 35 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 11 | matara
# Processing Record 37 of Set 11 | talisay
# Processing Record 38 of Set 11 | udachnyy
# Processing Record 39 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 11 | argir
# Processing Record 41 of Set 11 | jalu
# Processing Record 42 of Set 11 | salinopolis
# Processing Record 43 of Set 11 | ibotirama
# Processing Record 44 of Set 11 | qandala
# Processing Record 45 of Set 11 | derzhavinsk
# Processing Record 46 of Set 11 | pahasu
# Processing Record 47 of Set 11 | westport
# Processing Record 48 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 11 | qujing
# Processing Record 50 of Set 11 | cap malheureux
# Processing Record 1 of Set 12 | vila velha
# Processing Record 2 of Set 12 | san luis
# Processing Record 3 of Set 12 | cody
# Processing Record 4 of Set 12 | sharan
# Processing Record 5 of Set 12 | eirunepe
# Processing Record 6 of Set 12 | tver
# Processing Record 7 of Set 12 | ha giang
# Processing Record 8 of Set 12 | doha
# Processing Record 9 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 12 | tokur
# Processing Record 11 of Set 12 | ipira
# Processing Record 12 of Set 12 | mersing
# Processing Record 13 of Set 12 | san jose
# Processing Record 14 of Set 12 | ranot
# Processing Record 15 of Set 12 | genhe
# Processing Record 16 of Set 12 | comodoro rivadavia
# Processing Record 17 of Set 12 | sao gabriel da cachoeira
# Processing Record 18 of Set 12 | purpe
# Processing Record 19 of Set 12 | norsup
# Processing Record 20 of Set 12 | loiza
# Processing Record 21 of Set 12 | balabac
# Processing Record 22 of Set 12 | klang
# Processing Record 23 of Set 12 | sibolga
# Processing Record 24 of Set 12 | sao joao batista
# Processing Record 25 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 12 | ulladulla
# Processing Record 27 of Set 12 | paracuru
# Processing Record 28 of Set 12 | shibarghan
# City not found. Skipping...
# Processing Record 29 of Set 12 | paita
# Processing Record 30 of Set 12 | yarada
# Processing Record 31 of Set 12 | aruja
# Processing Record 32 of Set 12 | benalla
# Processing Record 33 of Set 12 | aksarka
# Processing Record 34 of Set 12 | qiyang
# Processing Record 35 of Set 12 | marsabit
# Processing Record 36 of Set 12 | conceicao do araguaia
# Processing Record 37 of Set 12 | ladario
# Processing Record 38 of Set 12 | prince rupert
# Processing Record 39 of Set 12 | sangin
# Processing Record 40 of Set 12 | sao jose da coroa grande
# Processing Record 41 of Set 12 | beringovskiy
# Processing Record 42 of Set 12 | buenos aires
# Processing Record 43 of Set 12 | alenquer
# Processing Record 44 of Set 12 | tocopilla
# Processing Record 45 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 47 of Set 12 | ferme-neuve
# Processing Record 48 of Set 12 | ewa beach
# Processing Record 49 of Set 12 | el carmen
# Processing Record 50 of Set 12 | hobyo
# Processing Record 1 of Set 13 | adeje
# Processing Record 2 of Set 13 | kisangani
# Processing Record 3 of Set 13 | ygatimi
# Processing Record 4 of Set 13 | muli
# Processing Record 5 of Set 13 | solnechnyy
# Processing Record 6 of Set 13 | tezu
# Processing Record 7 of Set 13 | orchard homes
# Processing Record 8 of Set 13 | ivankiv
# Processing Record 9 of Set 13 | buala
# Processing Record 10 of Set 13 | tuatapere
# Processing Record 11 of Set 13 | cabra
# Processing Record 12 of Set 13 | cockburn town
# Processing Record 13 of Set 13 | kaeo
# Processing Record 14 of Set 13 | fez
# Processing Record 15 of Set 13 | katobu
# Processing Record 16 of Set 13 | cabo san lucas
# Processing Record 17 of Set 13 | berlevag
# Processing Record 18 of Set 13 | finnsnes
# Processing Record 19 of Set 13 | komsomolets
# Processing Record 20 of Set 13 | brae
# Processing Record 21 of Set 13 | port keats
# Processing Record 22 of Set 13 | walvis bay
# Processing Record 23 of Set 13 | ongandjera
# Processing Record 24 of Set 13 | kaohsiung
# Processing Record 25 of Set 13 | upata
# Processing Record 26 of Set 13 | kalemie
# Processing Record 27 of Set 13 | zhangye
# Processing Record 28 of Set 13 | taldan
# Processing Record 29 of Set 13 | savannah bight
# Processing Record 30 of Set 13 | la ronge
# Processing Record 31 of Set 13 | kurilsk
# Processing Record 32 of Set 13 | sorland
# Processing Record 33 of Set 13 | guarapari
# Processing Record 34 of Set 13 | lata
# Processing Record 35 of Set 13 | progreso
# Processing Record 36 of Set 13 | hervey bay
# Processing Record 37 of Set 13 | flinders
# Processing Record 38 of Set 13 | tolaga bay
# Processing Record 39 of Set 13 | faqirwali
# Processing Record 40 of Set 13 | bilibino
# Processing Record 41 of Set 13 | radomsko
# Processing Record 42 of Set 13 | hay river
# Processing Record 43 of Set 13 | berlin
# Processing Record 44 of Set 13 | sogne
# Processing Record 45 of Set 13 | morristown
# Processing Record 46 of Set 13 | kensington
# Processing Record 47 of Set 13 | vidim
# Processing Record 48 of Set 13 | birao
# Processing Record 49 of Set 13 | kongwa
# Processing Record 50 of Set 13 | alora
# Processing Record 1 of Set 14 | mae sai
# Processing Record 2 of Set 14 | panuco
# Processing Record 3 of Set 14 | eyl
# Processing Record 4 of Set 14 | brigantine
# Processing Record 5 of Set 14 | lima
# Processing Record 6 of Set 14 | katsuura
# Processing Record 7 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 14 | chom bung
# City not found. Skipping...
# Processing Record 9 of Set 14 | krasnaya gora
# Processing Record 10 of Set 14 | kahului
# Processing Record 11 of Set 14 | mmathubudukwane
# Processing Record 12 of Set 14 | cacequi
# Processing Record 13 of Set 14 | sao felix do xingu
# Processing Record 14 of Set 14 | burica
# City not found. Skipping...
# Processing Record 15 of Set 14 | san quintin
# Processing Record 16 of Set 14 | magadan
# Processing Record 17 of Set 14 | luganville
# Processing Record 18 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 19 of Set 14 | traverse city
# Processing Record 20 of Set 14 | whitehorse
# Processing Record 21 of Set 14 | pevek
# Processing Record 22 of Set 14 | amla
# Processing Record 23 of Set 14 | tongliao
# Processing Record 24 of Set 14 | matay
# Processing Record 25 of Set 14 | indramayu
# Processing Record 26 of Set 14 | rey bouba
# Processing Record 27 of Set 14 | khobi
# Processing Record 28 of Set 14 | sobolevo
# Processing Record 29 of Set 14 | saint-joseph
# Processing Record 30 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 14 | marawi
# Processing Record 32 of Set 14 | san andres
# Processing Record 33 of Set 14 | komsomolskiy
# Processing Record 34 of Set 14 | quisqueya
# Processing Record 35 of Set 14 | oranjestad
# Processing Record 36 of Set 14 | inuvik
# Processing Record 37 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 14 | lakes entrance
# Processing Record 39 of Set 14 | khash
# Processing Record 40 of Set 14 | labuan
# Processing Record 41 of Set 14 | calderitas
# Processing Record 42 of Set 14 | klaksvik
# Processing Record 43 of Set 14 | winchester
# Processing Record 44 of Set 14 | bad sooden-allendorf
# Processing Record 45 of Set 14 | conakry
# Processing Record 46 of Set 14 | tashla
# Processing Record 47 of Set 14 | ricardo palma
# Processing Record 48 of Set 14 | kotagiri
# Processing Record 49 of Set 14 | novyy urengoy
# Processing Record 50 of Set 14 | vila do maio
# Processing Record 1 of Set 15 | sindor
# Processing Record 2 of Set 15 | payson
# Processing Record 3 of Set 15 | gobabis
# Processing Record 4 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 15 | marsa matruh
# Processing Record 6 of Set 15 | roald
# Processing Record 7 of Set 15 | vanimo
# Processing Record 8 of Set 15 | altay
# Processing Record 9 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 15 | soyo
# Processing Record 12 of Set 15 | yacuiba
# Processing Record 13 of Set 15 | wampusirpi
# City not found. Skipping...
# Processing Record 14 of Set 15 | pacific grove
# Processing Record 15 of Set 15 | syracuse
# Processing Record 16 of Set 15 | nakusp
# Processing Record 17 of Set 15 | namibe
# Processing Record 18 of Set 15 | najran
# Processing Record 19 of Set 15 | puerto lempira
# Processing Record 20 of Set 15 | denpasar
# Processing Record 21 of Set 15 | karpogory
# Processing Record 22 of Set 15 | chunskiy
# Processing Record 23 of Set 15 | tessalit
# Processing Record 24 of Set 15 | myitkyina
# Processing Record 25 of Set 15 | hami
# Processing Record 26 of Set 15 | doka
# Processing Record 27 of Set 15 | guerande
# Processing Record 28 of Set 15 | huarmey
# Processing Record 29 of Set 15 | duiwelskloof
# Processing Record 30 of Set 15 | isangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        Albany  42.6001  -73.9662     65.52       broken clouds        84
# 1   Santa Maria -29.6842  -53.8069     67.30                mist       100
# 2  Punta Arenas -53.1500  -70.9167     44.71       broken clouds        65
# 3        Avarua -21.2078 -159.7750     78.85     overcast clouds        61
# 4     Busselton -33.6500  115.3333     52.86     overcast clouds        67
# 5        Samsun  41.2500   36.3333     61.00    scattered clouds        94
# 6       Ushuaia -54.8000  -68.3000     44.26       broken clouds        65
# 7         Kathu   7.9178   98.3332     84.69     overcast clouds        84
# 8     Caravelas -17.7125  -39.2481     73.67    scattered clouds        84
# 9          Poum -20.2333  164.0167     76.21    scattered clouds        67
#
#    Cloudiness  Wind Speed Country
# 0          52        2.80      US
# 1         100        5.75      BR
# 2          75       18.41      CL
# 3          87       14.97      CK
# 4          99        1.99      AU
# 5          40        3.44      TR
# 6          75        2.30      AR
# 7         100        4.90      TH
# 8          40        5.84      BR
# 9          30        7.40      NC

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     65.52        84          52
# 1   Santa Maria      BR -29.6842  -53.8069     67.30       100         100
# 2  Punta Arenas      CL -53.1500  -70.9167     44.71        65          75
# 3        Avarua      CK -21.2078 -159.7750     78.85        61          87
# 4     Busselton      AU -33.6500  115.3333     52.86        67          99
# 5        Samsun      TR  41.2500   36.3333     61.00        94          40
# 6       Ushuaia      AR -54.8000  -68.3000     44.26        65          75
# 7         Kathu      TH   7.9178   98.3332     84.69        84         100
# 8     Caravelas      BR -17.7125  -39.2481     73.67        84          40
# 9          Poum      NC -20.2333  164.0167     76.21        67          30
#
#    Wind Speed Current Description
# 0        2.80       broken clouds
# 1        5.75                mist
# 2       18.41       broken clouds
# 3       14.97     overcast clouds
# 4        1.99     overcast clouds
# 5        3.44    scattered clouds
# 6        2.30       broken clouds
# 7        4.90     overcast clouds
# 8        5.84    scattered clouds
# 9        7.40    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name, index_label="City_ID")
